# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.txt',
#  'fruits.txt',
#  'Pandasjupytertest.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb',
#  'vegitable.txt']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3=pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6=pandas.read_csv("data.txt", header = None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df6.columns = ["ID", "Address", "City", "State", "Country", "Name", "Employees"]
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7=df6.set_index("ID")
df7
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6.set_index("ID", inplace=True)
df6
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6.set_index("Name", inplace=True, drop=False )
df6
# Out:
#                      Address           City             State Country  \
# Name
#  Madeira        3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df6.loc["Super River": "Sanchez","Country":"Employees"]
# Out:
#             Country         Name  Employees
# Name
# Super River     USA  Super River         25
# Ben's Shop      USA   Ben's Shop         10
# Sanchez         USA      Sanchez         12

# %%
df6.drop("City", 1)
# Out:
#                      Address             State Country         Name  Employees
# Name
#  Madeira        3666 21st St          CA 94114     USA      Madeira          8
# Bready Shop   735 Dolores St          CA 94119     USA  Bready Shop         15
# Super River      332 Hill St  California 94114     USA  Super River         25
# Ben's Shop      3995 23rd St          CA 94114     USA   Ben's Shop         10
# Sanchez      1056 Sanchez St        California     USA      Sanchez         12
# Richvalley   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df6.drop("Super River",0)
# Out:
#                      Address           City       State Country         Name  \
# Name
#  Madeira        3666 21st St  San Francisco    CA 94114     USA      Madeira
# Bready Shop   735 Dolores St  San Francisco    CA 94119     USA  Bready Shop
# Ben's Shop      3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop
# Sanchez      1056 Sanchez St  San Francisco  California     USA      Sanchez
# Richvalley   551 Alvarado St  San Francisco    CA 94114     USA   Richvalley
#
#              Employees
# Name
#  Madeira             8
# Bready Shop         15
# Ben's Shop          10
# Sanchez             12
# Richvalley          20

# %%
df6=df6.drop("Super River",0)

# %%
df6
# Out:
#                      Address           City       State Country         Name  \
# Name
#  Madeira        3666 21st St  San Francisco    CA 94114     USA      Madeira
# Bready Shop   735 Dolores St  San Francisco    CA 94119     USA  Bready Shop
# Ben's Shop      3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop
# Sanchez      1056 Sanchez St  San Francisco  California     USA      Sanchez
# Richvalley   551 Alvarado St  San Francisco    CA 94114     USA   Richvalley
#
#              Employees
# Name
#  Madeira             8
# Bready Shop         15
# Ben's Shop          10
# Sanchez             12
# Richvalley          20

# %%
df8=pandas.read_csv("data.txt", header = None)

# %%
df8
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df8.columns = ["ID", "Address", "City", "State", "Country", "Name", "Employees"]
df8
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df8.set_index("Name", inplace=True, drop=False )
df8
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df8["Continent"]=df8.shape[0]*["North America"]
df8
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees      Continent
# Name
#  Madeira         Madeira          8  North America
# Bready Shop  Bready Shop         15  North America
# Super River  Super River         25  North America
# Ben's Shop    Ben's Shop         10  North America
# Sanchez          Sanchez         12  North America
# Richvalley    Richvalley         20  North America

# %%
df8["Continent"]=df8["Country"]+ "," + "North America"
df8
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees          Continent
# Name
#  Madeira         Madeira          8  USA,North America
# Bready Shop  Bready Shop         15  USA,North America
# Super River  Super River         25  USA,North America
# Ben's Shop    Ben's Shop         10  USA,North America
# Sanchez          Sanchez         12  USA,North America
# Richvalley    Richvalley         20  USA,North America

# %%
df8_t=df8.T

# %%
df8_t
# Out:
# Name                 Madeira        Bready Shop        Super River  \
# ID                         1                  2                  3
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# Name              Ben's Shop            Sanchez         Richvalley
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# ...

# %%
df8.set_index("Address", inplace=True, drop=False )
df8
df8.drop("ID", 1)
df8_t=df8.T
df8_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# ID                         1                  2                  3
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# ...

# %%
df8.set_index("Address", inplace=True, drop=False )
df8
df8.drop("ID", 1)
df8
# Out:
#                  ID          Address           City             State Country  \
# Address
# 3666 21st St      1     3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    2   735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St       3      332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St      4     3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St   5  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name  Employees          Continent
# Address
# 3666 21st St         Madeira          8  USA,North America
# 735 Dolores St   Bready Shop         15  USA,North America
# 332 Hill St      Super River         25  USA,North America
# 3995 23rd St      Ben's Shop         10  USA,North America
# 1056 Sanchez St      Sanchez         12  USA,North America
# ...

# %%
df8_t["My Address"]=["My City"]
df8_t
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 df8_t["My Address"]=["My City"]
#       2 df8_t
#
# File c:\users\caudww\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3163, in DataFrame.__setitem__(self, key, value)
#    3160     self._setitem_array(key, value)
#    3161 else:
#    3162     # set column
# -> 3163     self._set_item(key, value)
#
# File c:\users\caudww\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3239, in DataFrame._set_item(self, key, value)
#    3229 """
#    3230 Add series to DataFrame in specified column.
#    3231
#    (...)
#    3236 ensure homogeneity.
#    3237 """
#    3238 self._ensure_valid_index(value)
# -> 3239 value = self._sanitize_column(key, value)
#    3240 NDFrame._set_item(self, key, value)
# ...

# %%
df8=pandas.read_csv("data.txt", header = None)
df8.columns = ["ID", "Address", "City", "State", "Country", "Name", "Employees"]
df8
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df8["Continent"]=df8["Country"]+ "," + "North America"
df8
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees          Continent
# 0          8  USA,North America
# 1         15  USA,North America
# 2         25  USA,North America
# 3         10  USA,North America
# 4         12  USA,North America
# 5         20  USA,North America

# %%
from geopy.geocoders import Nominatim

# %%
nom=Nominatim

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 nom.geocode("3995 23rd St, San Francisco, CA 94114")
#
# TypeError: geocode() missing 1 required positional argument: 'query'

# %%
nom=Nominatim()
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 nom=Nominatim()
#
# File c:\users\caudww\appdata\local\programs\python\python38\lib\site-packages\geopy\geocoders\nominatim.py:105, in Nominatim.__init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     101 self.domain = domain.strip('/')
#     103 if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104         and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105     raise ConfigurationError(
#     106         'Using Nominatim with default or sample `user_agent` "%s" is '
#     107         'strongly discouraged, as it violates Nominatim\'s ToS '
#     108         'https://operations.osmfoundation.org/policies/nominatim/ '
#     109         'and may possibly cause 403 and 429 HTTP errors. '
# ...
